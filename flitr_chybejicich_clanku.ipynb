# %%
import pandas as pd
import csv 
data = pd.read_csv ("ocisteny_layoffs.csv")
data.head()

# %%
data2 = pd.read_csv ("Layoffs.fyi_Tech_Layoffs_Tracker_Original.csv")
data2.head()

# %%
data3 = data[data ["text"].isna()]
data3["url"].to_csv("URLs.txt", index = False)
