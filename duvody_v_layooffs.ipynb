# %%
import pandas as pd
import json
import csv

# %%
df_data = pd.read_csv("ocisteny_layoffs.csv")
df_duvod = pd.read_csv("je_tam_duvod_vypovedi.csv")
df_duvod = df_duvod.rename(columns = {'id' : 'index'})
df_dataset = pd.merge(df_data, df_duvod, how='left')
df_dataset.to_csv('duvody_v_layoffs_14_05.csv')
df_dataset
# Out:
#       index        Company         Location HQ  # Laid Off       Date     %  \
# 0         0          Tract     London,Non-U.S.         NaN   3.4.2025   NaN
# 1         1     Automattic         SF Bay Area       281.0   2.4.2025   16%
# 2         2          Canva     Sydney,Non-U.S.        10.0   2.4.2025   NaN
# 3         3        WhyHive  Melbourne,Non-U.S.         NaN   2.4.2025  100%
# 4         4      Northvolt  Stockholm,Non-U.S.      2800.0  31.3.2025   62%
# ...     ...            ...                 ...         ...        ...   ...
# 4021   4021        Service         Los Angeles         NaN  16.3.2020  100%
# 4022   4022   HopSkipDrive         Los Angeles         8.0  13.3.2020   10%
# 4023   4023    Panda Squad         SF Bay Area         6.0  13.3.2020   75%
# 4024   4024  Tamara Mellon         Los Angeles        20.0  12.3.2020   40%
# 4025   4025       EasyPost      Salt Lake City        75.0  11.3.2020   NaN
#
# ...

# %%
df = pd.read_csv('ocistene_komplet.csv')
df
# Out:
#       index        Company         Location HQ  # Laid Off       Date     %  \
# 0         0          Tract     London,Non-U.S.         NaN   3.4.2025   NaN
# 1         1     Automattic         SF Bay Area       281.0   2.4.2025   16%
# 2         2          Canva     Sydney,Non-U.S.        10.0   2.4.2025   NaN
# 3         3        WhyHive  Melbourne,Non-U.S.         NaN   2.4.2025  100%
# 4         4      Northvolt  Stockholm,Non-U.S.      2800.0  31.3.2025   62%
# ...     ...            ...                 ...         ...        ...   ...
# 4021   4021        Service         Los Angeles         NaN  16.3.2020  100%
# 4022   4022   HopSkipDrive         Los Angeles         8.0  13.3.2020   10%
# 4023   4023    Panda Squad         SF Bay Area         6.0  13.3.2020   75%
# 4024   4024  Tamara Mellon         Los Angeles        20.0  12.3.2020   40%
# 4025   4025       EasyPost      Salt Lake City        75.0  11.3.2020   NaN
#
# ...
